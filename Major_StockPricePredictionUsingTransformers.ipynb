# %%
import math
import numpy as np
import pandas as pd

import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Input, Dense, Dropout, LayerNormalization, MultiHeadAttention, Add, GlobalAveragePooling1D

import yfinance as yf

# %%
def calculate_rsi(data, window=10):
    """Calculate Relative Strength Index"""
    delta = data.diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(window=window, min_periods=1).mean()
    avg_loss = loss.rolling(window=window, min_periods=1).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def calculate_roc(data, periods=10):
    """Calculate Rate of Change."""
    roc = ((data - data.shift(periods)) / data.shift(periods)) * 100
    return roc

def calculate_obv(data):
    """Calculate On-Balance Volume."""
    obv = [0]  # OBV starts with zero

    for i in range(1, len(data['Close'])):
        if data['Close'][i] > data['Close'][i - 1]:
            obv.append(obv[-1] + data['Volume'][i])
        elif data['Close'][i] < data['Close'][i - 1]:
            obv.append(obv[-1] - data['Volume'][i])
        else:
            obv.append(obv[-1])  # No change in OBV if closing prices are equal

    return pd.Series(obv, index=data.index)

def calculate_macd(data, short_window=12, long_window=26, signal_window=9):
    """Calculate MACD and Signal Line."""
    short_ema = data['Close'].ewm(span=short_window, adjust=False).mean()  # Short-term EMA
    long_ema = data['Close'].ewm(span=long_window, adjust=False).mean()    # Long-term EMA

    macd = short_ema - long_ema  # MACD line
    signal_line = macd.ewm(span=signal_window, adjust=False).mean()  # Signal line

    return macd, signal_line

def calculate_stochastic_oscillator(data, window=14):
    """Calculate Stochastic Oscillator."""
    low_min = data['Low'].rolling(window=window).min()
    high_max = data['High'].rolling(window=window).max()

    stoch_k = 100 * ((data['Close'] - low_min) / (high_max - low_min))
    stoch_d = stoch_k.rolling(window=3).mean()  # Stochastic D (3-period moving average)

    return stoch_k, stoch_d

def calculate_bollinger_bands(data, window=14, num_of_std=2):
    """Calculate Bollinger Bands."""
    rolling_mean = data.rolling(window=window).mean()
    rolling_std = data.rolling(window=window).std()
    upper_band = rolling_mean + (rolling_std * num_of_std)
    lower_band = rolling_mean - (rolling_std * num_of_std)

    return upper_band, lower_band

# %%
tickers = ['NVDA', 'TCS', 'GOOGL']

# %%
ticker_data_frames = []
stats = {}
for ticker in tickers:

    # Download historical data for the ticker
    data = yf.download(ticker, period="1mo", interval="5m")

    # Calculate the daily percentage change
    close = data['Close']
    upper, lower = calculate_bollinger_bands(close, window=14, num_of_std=2)
    width = upper - lower
    rsi = calculate_rsi(close, window=14)
    roc = calculate_roc(close, periods=14)
    volume = data['Volume']
    diff = data['Close'].diff(1)
    percent_change_close = data['Close'].pct_change() * 100

    # Create a DataFrame for the current ticker and append it to the list
    ticker_df = pd.DataFrame({
        ticker+'_close': close,
        ticker+'_width': width,
        ticker+'_rsi': rsi,
        ticker+'_roc': roc,
        ticker+'_volume': volume,
        ticker+'_diff': diff,
        ticker+'_percent_change_close': percent_change_close,
    })

    MEAN = ticker_df.mean()
    STD = ticker_df.std()

    # Keep track of mean and std
    for column in MEAN.index:
      stats[f"{column}_mean"] = MEAN[column]
      stats[f"{column}_std"] = STD[column]

    # Normalize the training features
    ticker_df = (ticker_df - MEAN) / STD

    ticker_data_frames.append(ticker_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Convert stats from dict to df
stats = pd.DataFrame([stats], index=[0])
stats.head()
# Out:
#    NVDA_close_mean  NVDA_close_std  NVDA_width_mean  NVDA_width_std  \
# 0       125.644783        7.700388         1.748619        1.518472
#
#    NVDA_rsi_mean  NVDA_rsi_std  NVDA_roc_mean  NVDA_roc_std  NVDA_volume_mean  \
# 0      52.264246      16.29716       0.155071      1.099816      3.185233e+06
#
#    NVDA_volume_std  ...  GOOGL_rsi_mean  GOOGL_rsi_std  GOOGL_roc_mean  \
# 0     2.829203e+06  ...       50.321979      17.214935        0.019465
#
#    GOOGL_roc_std  GOOGL_volume_mean  GOOGL_volume_std  GOOGL_diff_mean  \
# 0       0.483028      203002.920746      257829.57437         0.002017
#
#    GOOGL_diff_std  GOOGL_percent_change_close_mean  \
# 0        0.239265                         0.001358
#
#    GOOGL_percent_change_close_std
# 0                        0.146117
#
# [1 rows x 42 columns]

# %%
# Concatenate all ticker DataFrames
df = pd.concat(ticker_data_frames, axis=1)
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)
df.head()
# Out:
#                            NVDA_close  NVDA_width  NVDA_rsi  NVDA_roc  \
# Datetime
# 2024-09-18 11:25:00-04:00   -1.404459   -0.628106 -0.452766 -0.307053
# 2024-09-18 11:30:00-04:00   -1.440159   -0.538665 -0.553413 -0.369016
# 2024-09-18 11:35:00-04:00   -1.442172   -0.458558 -1.091174 -0.599493
# 2024-09-18 12:00:00-04:00   -1.519921    0.145529 -1.775819 -1.119232
# 2024-09-18 12:15:00-04:00   -1.460288   -0.141642 -0.817931 -0.532721
#
#                            NVDA_volume  NVDA_diff  NVDA_percent_change_close  \
# Datetime
# 2024-09-18 11:25:00-04:00    -0.164603   0.289794                   0.316935
# 2024-09-18 11:30:00-04:00    -0.518731  -0.775506                  -0.840750
# 2024-09-18 11:35:00-04:00    -0.514362  -0.075572                  -0.080466
# 2024-09-18 12:00:00-04:00    -0.291814   0.065568                   0.073851
# 2024-09-18 12:15:00-04:00    -0.509812   0.141655                   0.156458
#
#                            TCS_close  TCS_width   TCS_rsi  ...  TCS_volume  \
# Datetime                                                   ...
# 2024-09-18 11:25:00-04:00   1.050926  -0.128457  0.682803  ...    0.189547
# 2024-09-18 11:30:00-04:00   0.901638   0.033108 -0.099225  ...   -0.054021
# 2024-09-18 11:35:00-04:00   0.777984   0.495538 -0.707669  ...   -0.385075
# 2024-09-18 12:00:00-04:00   0.986945   0.570026 -0.194388  ...    0.250331
# 2024-09-18 12:15:00-04:00   1.409218   0.666273  0.275732  ...   -0.172983
#
#                            TCS_diff  TCS_percent_change_close  GOOGL_close  \
# Datetime
# 2024-09-18 11:25:00-04:00 -1.984714                 -1.684772    -2.513793
# 2024-09-18 11:30:00-04:00 -1.261064                 -1.116536    -2.613339
# 2024-09-18 11:35:00-04:00 -1.043609                 -0.949583    -2.657585
# 2024-09-18 12:00:00-04:00  1.777891                  1.623758    -2.761283
# 2024-09-18 12:15:00-04:00  3.587372                  3.169989    -2.502730
#
#                            GOOGL_width  GOOGL_rsi  GOOGL_roc  GOOGL_volume  \
# Datetime
# 2024-09-18 11:25:00-04:00    -0.614212  -0.713155  -0.364834     -0.301078
# 2024-09-18 11:30:00-04:00    -0.478638  -0.923524  -0.507835     -0.488155
# 2024-09-18 11:35:00-04:00    -0.340398  -1.307514  -0.708819     -0.448094
# 2024-09-18 12:00:00-04:00     0.069114  -1.742299  -1.090397     -0.459505
# 2024-09-18 12:15:00-04:00    -0.348564  -0.173098  -0.144250     -0.394601
#
#                            GOOGL_diff  GOOGL_percent_change_close
# Datetime
# 2024-09-18 11:25:00-04:00    0.493084                    0.506844
# 2024-09-18 11:30:00-04:00   -0.760707                   -0.782919
# 2024-09-18 11:35:00-04:00   -0.342798                   -0.353539
# 2024-09-18 12:00:00-04:00   -0.039745                   -0.041585
# 2024-09-18 12:15:00-04:00    0.325933                    0.334690
#
# [5 rows x 21 columns]

# %%
# Shift the df data to create labels
labels = df.shift(-1)

# Drop the last row in both percent_change_data and labels as it won't have a corresponding label
df = df.iloc[:-1]
labels = labels.iloc[:-1]

# %%
# Sequence len = 24 means that we have 2 hours of 5 min data
SEQUENCE_LEN = 24

# Function to create X-day sequences for each ticker
def create_sequences(data, labels, mean, std, sequence_length=SEQUENCE_LEN):
    sequences = []
    lab = []
    data_size = len(data)

    # + 12 because we want to predict the next hour
    for i in range(data_size - (sequence_length + 13)):
      if i == 0:
        continue

      sequences.append(data[i:i + sequence_length])
      lab.append([labels[i-1], labels[i + 12], mean[0], std[0]])

    for i in range(0, len(lab)):
      last_price_data = sequences[i][-1][0]
      last_price_label = lab[i][0]

      if not last_price_data == last_price_label:
        print(f"ERROR : {last_price_data=} and {last_price_label=} are not equal")

    return np.array(sequences), np.array(lab)

# %%
sequences_dict = {}
sequence_labels = {}
for ticker in tickers:

    # Extract close and volume data for the ticker
    close = df[ticker+'_close'].values
    width = df[ticker+'_width'].values
    rsi = df[ticker+'_rsi'].values
    roc = df[ticker+'_roc'].values
    volume = df[ticker+'_volume'].values
    diff = df[ticker+'_diff'].values
    pct_change = df[ticker+'_percent_change_close'].values

    # Combine close and volume data
    ticker_data = np.column_stack((close,
                                   width,
                                   rsi,
                                   roc,
                                   volume,
                                   diff,
                                   pct_change))

    # Generate sequences
    attribute = ticker+"_close"
    ticker_sequences, lab = create_sequences(ticker_data,
                                             labels[attribute].values[SEQUENCE_LEN-1:],
                                             stats[attribute+"_mean"].values,
                                             stats[attribute+"_std"].values)

    sequences_dict[ticker] = ticker_sequences
    sequence_labels[ticker] = lab

# %%
# Combine data and labels from all tickers
all_sequences = []
all_labels = []

for ticker in tickers:
    all_sequences.extend(sequences_dict[ticker])
    all_labels.extend(sequence_labels[ticker])

# Convert to numpy arrays
all_sequences = np.array(all_sequences)
all_labels = np.array(all_labels)

# %%
np.random.seed(42)
shuffled_indices = np.random.permutation(len(all_sequences))
all_sequences = all_sequences[shuffled_indices]
all_labels = all_labels[shuffled_indices]

train_size = int(len(all_sequences) * 0.9)

# Split sequences
train_sequences = all_sequences[:train_size]
train_labels    = all_labels[:train_size]

other_sequences = all_sequences[train_size:]
other_labels    = all_labels[train_size:]

shuffled_indices = np.random.permutation(len(other_sequences))
other_sequences = other_sequences[shuffled_indices]
other_labels = other_labels[shuffled_indices]

val_size = int(len(other_sequences) * 0.5)

validation_sequences = other_sequences[:val_size]
validation_labels = other_labels[:val_size]

test_sequences = other_sequences[val_size:]
test_labels = other_labels[val_size:]

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = LayerNormalization(epsilon=1e-6)(inputs)
    x = MultiHeadAttention(key_dim=head_size, num_heads=num_heads, dropout=dropout)(x, x)
    x = Add()([x, inputs])

    # Feed Forward Part
    y = LayerNormalization(epsilon=1e-6)(x)
    y = Dense(ff_dim, activation="relu")(y)
    y = Dropout(dropout)(y)
    y = Dense(inputs.shape[-1])(y)
    return Add()([y, x])

def build_transformer_model(input_shape, head_size, num_heads, ff_dim, num_layers, dropout=0):
    inputs = Input(shape=input_shape)
    x = inputs

    # Create multiple layers of the Transformer block
    for _ in range(num_layers):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    # Final part of the model
    x = GlobalAveragePooling1D()(x)
    x = LayerNormalization(epsilon=1e-6)(x)
    outputs = Dense(1, activation="linear")(x)

    # Compile model
    model = Model(inputs=inputs, outputs=outputs)
    return model

# Model parameters
input_shape = train_sequences.shape[1:]
head_size = 128
num_heads = 8
ff_dim = 512
num_layers = 6
dropout = 0.20

# Build the model
model = build_transformer_model(input_shape, head_size, num_heads, ff_dim, num_layers, dropout)
#model.summary()

# %%
def custom_mae_loss(y_true, y_pred):
    y_true_next = tf.cast(y_true[:, 1], tf.float64)
    y_pred_next = tf.cast(y_pred[:, 0], tf.float64)
    abs_error = tf.abs(y_true_next - y_pred_next)

    return tf.reduce_mean(abs_error)

def dir_acc(y_true, y_pred):
    mean, std = tf.cast(y_true[:, 2], tf.float64), tf.cast(y_true[:, 3], tf.float64)

    y_true_prev = (tf.cast(y_true[:, 0], tf.float64) * std) + mean
    y_true_next = (tf.cast(y_true[:, 1], tf.float64) * std) + mean
    y_pred_next = (tf.cast(y_pred[:, 0], tf.float64) * std) + mean

    true_change = y_true_next - y_true_prev
    pred_change = y_pred_next - y_true_prev

    correct_direction = tf.equal(tf.sign(true_change), tf.sign(pred_change))

    return tf.reduce_mean(tf.cast(correct_direction, tf.float64))

# %%
# Compile the model
optimizer = tf.keras.optimizers.Adam()
model.compile(optimizer=optimizer, loss=custom_mae_loss, metrics=[dir_acc])

# %%
# Define a callback to save the best model
checkpoint_callback_train = ModelCheckpoint(
    "transformer_train_model.keras",  # Filepath to save the best model
    monitor="dir_acc",  #"loss",  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode="max",  # Minimize the monitored metric
    verbose=1,  # Display progress
)

# Define a callback to save the best model
checkpoint_callback_val = ModelCheckpoint(
    "transformer_val_model.keras",  # Filepath to save the best model
    monitor="val_dir_acc", #"val_loss",  # Metric to monitor
    save_best_only=True,  # Save only the best model
    mode="max",  # Minimize the monitored metric
    verbose=1,  # Display progress
)

def get_lr_callback(batch_size=16, mode='cos', epochs=500, plot=False):
    lr_start, lr_max, lr_min = 0.0001, 0.005, 0.00001  # Adjust learning rate boundaries
    lr_ramp_ep = int(0.30 * epochs)  # 30% of epochs for warm-up
    lr_sus_ep = max(0, int(0.10 * epochs) - lr_ramp_ep)  # Optional sustain phase, adjust as needed

    def lrfn(epoch):
        if epoch < lr_ramp_ep:  # Warm-up phase
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
        elif epoch < lr_ramp_ep + lr_sus_ep:  # Sustain phase at max learning rate
            lr = lr_max
        elif mode == 'cos':
            decay_total_epochs, decay_epoch_index = epochs - lr_ramp_ep - lr_sus_ep, epoch - lr_ramp_ep - lr_sus_ep
            phase = math.pi * decay_epoch_index / decay_total_epochs
            lr = (lr_max - lr_min) * 0.5 * (1 + math.cos(phase)) + lr_min
        else:
            lr = lr_min  # Default to minimum learning rate if mode is not recognized

        return lr

    if plot:  # Plot learning rate curve if plot is True
        plt.figure(figsize=(10, 5))
        plt.plot(np.arange(epochs), [lrfn(epoch) for epoch in np.arange(epochs)], marker='o')
        plt.xlabel('Epoch')
        plt.ylabel('Learning Rate')
        plt.title('Learning Rate Scheduler')
        plt.show()

    return tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

# %%
BATCH_SIZE = 64
EPOCHS = 100
model.fit(train_sequences, train_labels,
          validation_data=(validation_sequences, validation_labels),
          epochs=EPOCHS,
          batch_size=BATCH_SIZE,
          shuffle=True,
          callbacks=[checkpoint_callback_train, checkpoint_callback_val, get_lr_callback(batch_size=BATCH_SIZE, epochs=EPOCHS)])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.0001.
# Epoch 1/100
# 36/38 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dir_acc: 0.8681 - loss: 0.0835
# Epoch 1: dir_acc did not improve from 0.87599
#
# Epoch 1: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - dir_acc: 0.8683 - loss: 0.0835 - val_dir_acc: 0.8507 - val_loss: 0.1044 - learning_rate: 1.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.00026333333333333336.
# Epoch 2/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8666 - loss: 0.0858
# Epoch 2: dir_acc did not improve from 0.87599
#
# Epoch 2: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8667 - loss: 0.0858 - val_dir_acc: 0.8003 - val_loss: 0.1078 - learning_rate: 2.6333e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00042666666666666667.
# Epoch 3/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8661 - loss: 0.0873
# Epoch 3: dir_acc did not improve from 0.87599
#
# Epoch 3: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8659 - loss: 0.0874 - val_dir_acc: 0.7951 - val_loss: 0.1106 - learning_rate: 4.2667e-04
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.00059.
# Epoch 4/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8648 - loss: 0.0874
# Epoch 4: dir_acc did not improve from 0.87599
#
# Epoch 4: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8646 - loss: 0.0875 - val_dir_acc: 0.8003 - val_loss: 0.1113 - learning_rate: 5.9000e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0007533333333333334.
# Epoch 5/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8619 - loss: 0.0886
# Epoch 5: dir_acc did not improve from 0.87599
#
# Epoch 5: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - dir_acc: 0.8616 - loss: 0.0887 - val_dir_acc: 0.7795 - val_loss: 0.1140 - learning_rate: 7.5333e-04
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.0009166666666666668.
# Epoch 6/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8509 - loss: 0.0929
# Epoch 6: dir_acc did not improve from 0.87599
#
# Epoch 6: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8510 - loss: 0.0928 - val_dir_acc: 0.8403 - val_loss: 0.1106 - learning_rate: 9.1667e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 0.00108.
# Epoch 7/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dir_acc: 0.8599 - loss: 0.0911
# Epoch 7: dir_acc did not improve from 0.87599
#
# Epoch 7: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dir_acc: 0.8594 - loss: 0.0914 - val_dir_acc: 0.8559 - val_loss: 0.1078 - learning_rate: 0.0011
#
# Epoch 8: LearningRateScheduler setting learning rate to 0.0012433333333333335.
# Epoch 8/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dir_acc: 0.8444 - loss: 0.0991
# Epoch 8: dir_acc did not improve from 0.87599
#
# Epoch 8: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - dir_acc: 0.8438 - loss: 0.0992 - val_dir_acc: 0.8056 - val_loss: 0.1071 - learning_rate: 0.0012
#
# Epoch 9: LearningRateScheduler setting learning rate to 0.0014066666666666667.
# Epoch 9/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - dir_acc: 0.8406 - loss: 0.0992
# Epoch 9: dir_acc did not improve from 0.87599
#
# Epoch 9: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - dir_acc: 0.8406 - loss: 0.0993 - val_dir_acc: 0.8403 - val_loss: 0.1167 - learning_rate: 0.0014
#
# Epoch 10: LearningRateScheduler setting learning rate to 0.00157.
# Epoch 10/100
# 36/38 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dir_acc: 0.8434 - loss: 0.1067
# Epoch 10: dir_acc did not improve from 0.87599
#
# Epoch 10: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - dir_acc: 0.8431 - loss: 0.1068 - val_dir_acc: 0.8455 - val_loss: 0.1277 - learning_rate: 0.0016
#
# Epoch 11: LearningRateScheduler setting learning rate to 0.0017333333333333335.
# Epoch 11/100
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - dir_acc: 0.8420 - loss: 0.1015
# Epoch 11: dir_acc did not improve from 0.87599
#
# Epoch 11: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - dir_acc: 0.8419 - loss: 0.1015 - val_dir_acc: 0.7188 - val_loss: 0.1175 - learning_rate: 0.0017
#
# Epoch 12: LearningRateScheduler setting learning rate to 0.0018966666666666667.
# Epoch 12/100
# 36/38 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - dir_acc: 0.8435 - loss: 0.1018
# Epoch 12: dir_acc did not improve from 0.87599
#
# Epoch 12: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - dir_acc: 0.8427 - loss: 0.1020 - val_dir_acc: 0.7639 - val_loss: 0.1345 - learning_rate: 0.0019
#
# Epoch 13: LearningRateScheduler setting learning rate to 0.0020599999999999998.
# Epoch 13/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - dir_acc: 0.8358 - loss: 0.1139
# Epoch 13: dir_acc did not improve from 0.87599
#
# Epoch 13: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - dir_acc: 0.8346 - loss: 0.1141 - val_dir_acc: 0.8247 - val_loss: 0.1217 - learning_rate: 0.0021
#
# Epoch 14: LearningRateScheduler setting learning rate to 0.0022233333333333332.
# Epoch 14/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - dir_acc: 0.8384 - loss: 0.1107
# Epoch 14: dir_acc did not improve from 0.87599
#
# Epoch 14: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - dir_acc: 0.8383 - loss: 0.1107 - val_dir_acc: 0.7847 - val_loss: 0.1258 - learning_rate: 0.0022
#
# Epoch 15: LearningRateScheduler setting learning rate to 0.0023866666666666667.
# Epoch 15/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dir_acc: 0.8388 - loss: 0.1072
# Epoch 15: dir_acc did not improve from 0.87599
#
# Epoch 15: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - dir_acc: 0.8385 - loss: 0.1075 - val_dir_acc: 0.7795 - val_loss: 0.1299 - learning_rate: 0.0024
#
# Epoch 16: LearningRateScheduler setting learning rate to 0.0025499999999999997.
# Epoch 16/100
# 36/38 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - dir_acc: 0.8147 - loss: 0.1197
# Epoch 16: dir_acc did not improve from 0.87599
#
# Epoch 16: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - dir_acc: 0.8152 - loss: 0.1194 - val_dir_acc: 0.7795 - val_loss: 0.1256 - learning_rate: 0.0026
#
# Epoch 17: LearningRateScheduler setting learning rate to 0.0027133333333333332.
# Epoch 17/100
# 36/38 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dir_acc: 0.8342 - loss: 0.1088
# Epoch 17: dir_acc did not improve from 0.87599
#
# Epoch 17: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - dir_acc: 0.8336 - loss: 0.1092 - val_dir_acc: 0.7378 - val_loss: 0.1297 - learning_rate: 0.0027
#
# Epoch 18: LearningRateScheduler setting learning rate to 0.0028766666666666667.
# Epoch 18/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - dir_acc: 0.8253 - loss: 0.1180
# Epoch 18: dir_acc did not improve from 0.87599
#
# Epoch 18: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - dir_acc: 0.8242 - loss: 0.1180 - val_dir_acc: 0.8455 - val_loss: 0.1201 - learning_rate: 0.0029
#
# Epoch 19: LearningRateScheduler setting learning rate to 0.0030399999999999997.
# Epoch 19/100
# 36/38 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - dir_acc: 0.8228 - loss: 0.1142
# Epoch 19: dir_acc did not improve from 0.87599
#
# Epoch 19: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - dir_acc: 0.8222 - loss: 0.1144 - val_dir_acc: 0.8038 - val_loss: 0.1395 - learning_rate: 0.0030
#
# Epoch 20: LearningRateScheduler setting learning rate to 0.003203333333333333.
# Epoch 20/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dir_acc: 0.8120 - loss: 0.1192
# Epoch 20: dir_acc did not improve from 0.87599
#
# Epoch 20: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - dir_acc: 0.8119 - loss: 0.1193 - val_dir_acc: 0.8455 - val_loss: 0.1262 - learning_rate: 0.0032
#
# Epoch 21: LearningRateScheduler setting learning rate to 0.0033666666666666667.
# Epoch 21/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8125 - loss: 0.1200
# Epoch 21: dir_acc did not improve from 0.87599
#
# Epoch 21: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8118 - loss: 0.1202 - val_dir_acc: 0.8403 - val_loss: 0.1321 - learning_rate: 0.0034
#
# Epoch 22: LearningRateScheduler setting learning rate to 0.0035299999999999997.
# Epoch 22/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8208 - loss: 0.1191
# Epoch 22: dir_acc did not improve from 0.87599
#
# Epoch 22: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8200 - loss: 0.1192 - val_dir_acc: 0.7639 - val_loss: 0.1293 - learning_rate: 0.0035
#
# Epoch 23: LearningRateScheduler setting learning rate to 0.003693333333333333.
# Epoch 23/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8008 - loss: 0.1197
# Epoch 23: dir_acc did not improve from 0.87599
#
# Epoch 23: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8013 - loss: 0.1196 - val_dir_acc: 0.7240 - val_loss: 0.1280 - learning_rate: 0.0037
#
# Epoch 24: LearningRateScheduler setting learning rate to 0.0038566666666666667.
# Epoch 24/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8088 - loss: 0.1212
# Epoch 24: dir_acc did not improve from 0.87599
#
# Epoch 24: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8088 - loss: 0.1212 - val_dir_acc: 0.8299 - val_loss: 0.1412 - learning_rate: 0.0039
#
# Epoch 25: LearningRateScheduler setting learning rate to 0.00402.
# Epoch 25/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8113 - loss: 0.1240
# Epoch 25: dir_acc did not improve from 0.87599
#
# Epoch 25: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8112 - loss: 0.1242 - val_dir_acc: 0.8403 - val_loss: 0.1267 - learning_rate: 0.0040
#
# Epoch 26: LearningRateScheduler setting learning rate to 0.004183333333333334.
# Epoch 26/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8105 - loss: 0.1329
# Epoch 26: dir_acc did not improve from 0.87599
#
# Epoch 26: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8105 - loss: 0.1328 - val_dir_acc: 0.8507 - val_loss: 0.1340 - learning_rate: 0.0042
#
# Epoch 27: LearningRateScheduler setting learning rate to 0.004346666666666667.
# Epoch 27/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8071 - loss: 0.1215
# Epoch 27: dir_acc did not improve from 0.87599
#
# Epoch 27: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8072 - loss: 0.1214 - val_dir_acc: 0.7483 - val_loss: 0.1549 - learning_rate: 0.0043
#
# Epoch 28: LearningRateScheduler setting learning rate to 0.00451.
# Epoch 28/100
# 35/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8247 - loss: 0.1293
# Epoch 28: dir_acc did not improve from 0.87599
#
# Epoch 28: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8237 - loss: 0.1289 - val_dir_acc: 0.7639 - val_loss: 0.1537 - learning_rate: 0.0045
#
# Epoch 29: LearningRateScheduler setting learning rate to 0.004673333333333334.
# Epoch 29/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8045 - loss: 0.1255
# Epoch 29: dir_acc did not improve from 0.87599
#
# Epoch 29: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8045 - loss: 0.1254 - val_dir_acc: 0.8090 - val_loss: 0.1496 - learning_rate: 0.0047
#
# Epoch 30: LearningRateScheduler setting learning rate to 0.004836666666666667.
# Epoch 30/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8108 - loss: 0.1210
# Epoch 30: dir_acc did not improve from 0.87599
#
# Epoch 30: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8101 - loss: 0.1218 - val_dir_acc: 0.8351 - val_loss: 0.1695 - learning_rate: 0.0048
#
# Epoch 31: LearningRateScheduler setting learning rate to 0.005.
# Epoch 31/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8090 - loss: 0.1327
# Epoch 31: dir_acc did not improve from 0.87599
#
# Epoch 31: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8090 - loss: 0.1324 - val_dir_acc: 0.8090 - val_loss: 0.1450 - learning_rate: 0.0050
#
# Epoch 32: LearningRateScheduler setting learning rate to 0.00499748770102058.
# Epoch 32/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dir_acc: 0.7774 - loss: 0.1331
# Epoch 32: dir_acc did not improve from 0.87599
#
# Epoch 32: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - dir_acc: 0.7774 - loss: 0.1333 - val_dir_acc: 0.6823 - val_loss: 0.1757 - learning_rate: 0.0050
#
# Epoch 33: LearningRateScheduler setting learning rate to 0.0049899558635181215.
# Epoch 33/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - dir_acc: 0.8042 - loss: 0.1331
# Epoch 33: dir_acc did not improve from 0.87599
#
# Epoch 33: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - dir_acc: 0.8047 - loss: 0.1329 - val_dir_acc: 0.7743 - val_loss: 0.1484 - learning_rate: 0.0050
#
# Epoch 34: LearningRateScheduler setting learning rate to 0.004977419655610997.
# Epoch 34/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dir_acc: 0.8112 - loss: 0.1213
# Epoch 34: dir_acc did not improve from 0.87599
#
# Epoch 34: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - dir_acc: 0.8108 - loss: 0.1215 - val_dir_acc: 0.7882 - val_loss: 0.1573 - learning_rate: 0.0050
#
# Epoch 35: LearningRateScheduler setting learning rate to 0.004959904323553581.
# Epoch 35/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.7868 - loss: 0.1249
# Epoch 35: dir_acc did not improve from 0.87599
#
# Epoch 35: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.7870 - loss: 0.1251 - val_dir_acc: 0.7934 - val_loss: 0.1512 - learning_rate: 0.0050
#
# Epoch 36: LearningRateScheduler setting learning rate to 0.0049374451408936496.
# Epoch 36/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.7983 - loss: 0.1308
# Epoch 36: dir_acc did not improve from 0.87599
#
# Epoch 36: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - dir_acc: 0.7988 - loss: 0.1305 - val_dir_acc: 0.8403 - val_loss: 0.1397 - learning_rate: 0.0049
#
# Epoch 37: LearningRateScheduler setting learning rate to 0.004910087337436154.
# Epoch 37/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.7930 - loss: 0.1355
# Epoch 37: dir_acc did not improve from 0.87599
#
# Epoch 37: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.7923 - loss: 0.1357 - val_dir_acc: 0.8611 - val_loss: 0.1398 - learning_rate: 0.0049
#
# Epoch 38: LearningRateScheduler setting learning rate to 0.004877886008156408.
# Epoch 38/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8002 - loss: 0.1332
# Epoch 38: dir_acc did not improve from 0.87599
#
# Epoch 38: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8005 - loss: 0.1329 - val_dir_acc: 0.7587 - val_loss: 0.1501 - learning_rate: 0.0049
#
# Epoch 39: LearningRateScheduler setting learning rate to 0.004840906002246144.
# Epoch 39/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8248 - loss: 0.1210
# Epoch 39: dir_acc did not improve from 0.87599
#
# Epoch 39: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8235 - loss: 0.1216 - val_dir_acc: 0.8455 - val_loss: 0.1435 - learning_rate: 0.0048
#
# Epoch 40: LearningRateScheduler setting learning rate to 0.00479922179251587.
# Epoch 40/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8080 - loss: 0.1288
# Epoch 40: dir_acc did not improve from 0.87599
#
# Epoch 40: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8072 - loss: 0.1288 - val_dir_acc: 0.7639 - val_loss: 0.1419 - learning_rate: 0.0048
#
# Epoch 41: LearningRateScheduler setting learning rate to 0.0047529173254165355.
# Epoch 41/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8051 - loss: 0.1221
# Epoch 41: dir_acc did not improve from 0.87599
#
# Epoch 41: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8054 - loss: 0.1222 - val_dir_acc: 0.7691 - val_loss: 0.1231 - learning_rate: 0.0048
#
# Epoch 42: LearningRateScheduler setting learning rate to 0.004702085851982562.
# Epoch 42/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8175 - loss: 0.1214
# Epoch 42: dir_acc did not improve from 0.87599
#
# Epoch 42: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8170 - loss: 0.1217 - val_dir_acc: 0.8351 - val_loss: 0.1549 - learning_rate: 0.0047
#
# Epoch 43: LearningRateScheduler setting learning rate to 0.004646829740036656.
# Epoch 43/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8041 - loss: 0.1236
# Epoch 43: dir_acc did not improve from 0.87599
#
# Epoch 43: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8044 - loss: 0.1234 - val_dir_acc: 0.8802 - val_loss: 0.1271 - learning_rate: 0.0046
#
# Epoch 44: LearningRateScheduler setting learning rate to 0.00458726026803465.
# Epoch 44/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8114 - loss: 0.1169
# Epoch 44: dir_acc did not improve from 0.87599
#
# Epoch 44: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8114 - loss: 0.1170 - val_dir_acc: 0.6927 - val_loss: 0.1738 - learning_rate: 0.0046
#
# Epoch 45: LearningRateScheduler setting learning rate to 0.004523497400965494.
# Epoch 45/100
# 36/38 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dir_acc: 0.8148 - loss: 0.1205
# Epoch 45: dir_acc did not improve from 0.87599
#
# Epoch 45: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - dir_acc: 0.8160 - loss: 0.1202 - val_dir_acc: 0.7743 - val_loss: 0.1390 - learning_rate: 0.0045
#
# Epoch 46: LearningRateScheduler setting learning rate to 0.004455669548757734.
# Epoch 46/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dir_acc: 0.8361 - loss: 0.1064
# Epoch 46: dir_acc did not improve from 0.87599
#
# Epoch 46: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - dir_acc: 0.8358 - loss: 0.1066 - val_dir_acc: 0.8351 - val_loss: 0.1197 - learning_rate: 0.0045
#
# Epoch 47: LearningRateScheduler setting learning rate to 0.00438391330767901.
# Epoch 47/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - dir_acc: 0.8420 - loss: 0.1072
# Epoch 47: dir_acc did not improve from 0.87599
#
# Epoch 47: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - dir_acc: 0.8416 - loss: 0.1077 - val_dir_acc: 0.6771 - val_loss: 0.1529 - learning_rate: 0.0044
#
# Epoch 48: LearningRateScheduler setting learning rate to 0.004308373185249342.
# Epoch 48/100
# 36/38 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - dir_acc: 0.8171 - loss: 0.1190
# Epoch 48: dir_acc did not improve from 0.87599
#
# Epoch 48: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - dir_acc: 0.8171 - loss: 0.1187 - val_dir_acc: 0.8403 - val_loss: 0.1327 - learning_rate: 0.0043
#
# Epoch 49: LearningRateScheduler setting learning rate to 0.004229201309222228.
# Epoch 49/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8159 - loss: 0.1096
# Epoch 49: dir_acc did not improve from 0.87599
#
# Epoch 49: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8166 - loss: 0.1096 - val_dir_acc: 0.7292 - val_loss: 0.1484 - learning_rate: 0.0042
#
# Epoch 50: LearningRateScheduler setting learning rate to 0.0041465571212195825.
# Epoch 50/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8019 - loss: 0.1157
# Epoch 50: dir_acc did not improve from 0.87599
#
# Epoch 50: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8020 - loss: 0.1158 - val_dir_acc: 0.8056 - val_loss: 0.1235 - learning_rate: 0.0041
#
# Epoch 51: LearningRateScheduler setting learning rate to 0.0040606070556375405.
# Epoch 51/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8080 - loss: 0.1095
# Epoch 51: dir_acc did not improve from 0.87599
#
# Epoch 51: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8086 - loss: 0.1095 - val_dir_acc: 0.8403 - val_loss: 0.1340 - learning_rate: 0.0041
#
# Epoch 52: LearningRateScheduler setting learning rate to 0.00397152420446972.
# Epoch 52/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8364 - loss: 0.1072
# Epoch 52: dir_acc did not improve from 0.87599
#
# Epoch 52: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8362 - loss: 0.1075 - val_dir_acc: 0.8906 - val_loss: 0.1231 - learning_rate: 0.0040
#
# Epoch 53: LearningRateScheduler setting learning rate to 0.0038794879687229964.
# Epoch 53/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8337 - loss: 0.1120
# Epoch 53: dir_acc did not improve from 0.87599
#
# Epoch 53: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8336 - loss: 0.1120 - val_dir_acc: 0.9062 - val_loss: 0.1263 - learning_rate: 0.0039
#
# Epoch 54: LearningRateScheduler setting learning rate to 0.0037846836971277367.
# Epoch 54/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8168 - loss: 0.1061
# Epoch 54: dir_acc did not improve from 0.87599
#
# Epoch 54: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8171 - loss: 0.1060 - val_dir_acc: 0.7899 - val_loss: 0.1217 - learning_rate: 0.0038
#
# Epoch 55: LearningRateScheduler setting learning rate to 0.003687302312870132.
# Epoch 55/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8313 - loss: 0.1010
# Epoch 55: dir_acc did not improve from 0.87599
#
# Epoch 55: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8317 - loss: 0.1010 - val_dir_acc: 0.7951 - val_loss: 0.1210 - learning_rate: 0.0037
#
# Epoch 56: LearningRateScheduler setting learning rate to 0.0035875399290983077.
# Epoch 56/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8383 - loss: 0.1061
# Epoch 56: dir_acc did not improve from 0.87599
#
# Epoch 56: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8378 - loss: 0.1061 - val_dir_acc: 0.7292 - val_loss: 0.1223 - learning_rate: 0.0036
#
# Epoch 57: LearningRateScheduler setting learning rate to 0.00348559745397654.
# Epoch 57/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8384 - loss: 0.1020
# Epoch 57: dir_acc did not improve from 0.87599
#
# Epoch 57: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8382 - loss: 0.1020 - val_dir_acc: 0.8142 - val_loss: 0.1385 - learning_rate: 0.0035
#
# Epoch 58: LearningRateScheduler setting learning rate to 0.0033816801860829505.
# Epoch 58/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8337 - loss: 0.1042
# Epoch 58: dir_acc did not improve from 0.87599
#
# Epoch 58: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8335 - loss: 0.1042 - val_dir_acc: 0.8142 - val_loss: 0.1245 - learning_rate: 0.0034
#
# Epoch 59: LearningRateScheduler setting learning rate to 0.0032759974009654944.
# Epoch 59/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dir_acc: 0.8363 - loss: 0.1018
# Epoch 59: dir_acc did not improve from 0.87599
#
# Epoch 59: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - dir_acc: 0.8364 - loss: 0.1019 - val_dir_acc: 0.7743 - val_loss: 0.1283 - learning_rate: 0.0033
#
# Epoch 60: LearningRateScheduler setting learning rate to 0.0031687619296888545.
# Epoch 60/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - dir_acc: 0.8467 - loss: 0.1024
# Epoch 60: dir_acc did not improve from 0.87599
#
# Epoch 60: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - dir_acc: 0.8467 - loss: 0.1027 - val_dir_acc: 0.7691 - val_loss: 0.1307 - learning_rate: 0.0032
#
# Epoch 61: LearningRateScheduler setting learning rate to 0.003060189730221005.
# Epoch 61/100
# 36/38 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dir_acc: 0.8547 - loss: 0.1057
# Epoch 61: dir_acc did not improve from 0.87599
#
# Epoch 61: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - dir_acc: 0.8538 - loss: 0.1055 - val_dir_acc: 0.7135 - val_loss: 0.1339 - learning_rate: 0.0031
#
# Epoch 62: LearningRateScheduler setting learning rate to 0.002950499452522599.
# Epoch 62/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8439 - loss: 0.1058
# Epoch 62: dir_acc did not improve from 0.87599
#
# Epoch 62: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8441 - loss: 0.1057 - val_dir_acc: 0.8351 - val_loss: 0.1210 - learning_rate: 0.0030
#
# Epoch 63: LearningRateScheduler setting learning rate to 0.0028399119982150506.
# Epoch 63/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8398 - loss: 0.0975
# Epoch 63: dir_acc did not improve from 0.87599
#
# Epoch 63: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8402 - loss: 0.0975 - val_dir_acc: 0.8507 - val_loss: 0.1123 - learning_rate: 0.0028
#
# Epoch 64: LearningRateScheduler setting learning rate to 0.002728650075714067.
# Epoch 64/100
# 35/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8475 - loss: 0.0945
# Epoch 64: dir_acc did not improve from 0.87599
#
# Epoch 64: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8467 - loss: 0.0951 - val_dir_acc: 0.8299 - val_loss: 0.1272 - learning_rate: 0.0027
#
# Epoch 65: LearningRateScheduler setting learning rate to 0.0026169377517245352.
# Epoch 65/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8585 - loss: 0.0929
# Epoch 65: dir_acc did not improve from 0.87599
#
# Epoch 65: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8581 - loss: 0.0930 - val_dir_acc: 0.8663 - val_loss: 0.1316 - learning_rate: 0.0026
#
# Epoch 66: LearningRateScheduler setting learning rate to 0.0025050000000000003.
# Epoch 66/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8544 - loss: 0.1002
# Epoch 66: dir_acc did not improve from 0.87599
#
# Epoch 66: val_dir_acc did not improve from 0.91146
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8541 - loss: 0.1001 - val_dir_acc: 0.8906 - val_loss: 0.1150 - learning_rate: 0.0025
#
# Epoch 67: LearningRateScheduler setting learning rate to 0.0023930622482754658.
# Epoch 67/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8355 - loss: 0.0945
# Epoch 67: dir_acc did not improve from 0.87599
#
# Epoch 67: val_dir_acc improved from 0.91146 to 0.92188, saving model to transformer_val_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - dir_acc: 0.8362 - loss: 0.0945 - val_dir_acc: 0.9219 - val_loss: 0.1128 - learning_rate: 0.0024
#
# Epoch 68: LearningRateScheduler setting learning rate to 0.002281349924285934.
# Epoch 68/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8450 - loss: 0.0932
# Epoch 68: dir_acc did not improve from 0.87599
#
# Epoch 68: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8459 - loss: 0.0931 - val_dir_acc: 0.9115 - val_loss: 0.1117 - learning_rate: 0.0023
#
# Epoch 69: LearningRateScheduler setting learning rate to 0.00217008800178495.
# Epoch 69/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8684 - loss: 0.0939
# Epoch 69: dir_acc did not improve from 0.87599
#
# Epoch 69: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8678 - loss: 0.0940 - val_dir_acc: 0.8194 - val_loss: 0.1148 - learning_rate: 0.0022
#
# Epoch 70: LearningRateScheduler setting learning rate to 0.002059500547477402.
# Epoch 70/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8458 - loss: 0.0919
# Epoch 70: dir_acc did not improve from 0.87599
#
# Epoch 70: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8464 - loss: 0.0918 - val_dir_acc: 0.8611 - val_loss: 0.1133 - learning_rate: 0.0021
#
# Epoch 71: LearningRateScheduler setting learning rate to 0.001949810269778996.
# Epoch 71/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dir_acc: 0.8539 - loss: 0.0919
# Epoch 71: dir_acc did not improve from 0.87599
#
# Epoch 71: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - dir_acc: 0.8541 - loss: 0.0918 - val_dir_acc: 0.7951 - val_loss: 0.1114 - learning_rate: 0.0019
#
# Epoch 72: LearningRateScheduler setting learning rate to 0.0018412380703111465.
# Epoch 72/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - dir_acc: 0.8657 - loss: 0.0878
# Epoch 72: dir_acc did not improve from 0.87599
#
# Epoch 72: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - dir_acc: 0.8655 - loss: 0.0879 - val_dir_acc: 0.8611 - val_loss: 0.1119 - learning_rate: 0.0018
#
# Epoch 73: LearningRateScheduler setting learning rate to 0.0017340025990345066.
# Epoch 73/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8633 - loss: 0.0866
# Epoch 73: dir_acc did not improve from 0.87599
#
# Epoch 73: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8632 - loss: 0.0867 - val_dir_acc: 0.8767 - val_loss: 0.1087 - learning_rate: 0.0017
#
# Epoch 74: LearningRateScheduler setting learning rate to 0.0016283198139170505.
# Epoch 74/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8717 - loss: 0.0855
# Epoch 74: dir_acc did not improve from 0.87599
#
# Epoch 74: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8714 - loss: 0.0856 - val_dir_acc: 0.8108 - val_loss: 0.1103 - learning_rate: 0.0016
#
# Epoch 75: LearningRateScheduler setting learning rate to 0.0015244025460234615.
# Epoch 75/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8590 - loss: 0.0838
# Epoch 75: dir_acc did not improve from 0.87599
#
# Epoch 75: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8593 - loss: 0.0839 - val_dir_acc: 0.8559 - val_loss: 0.1073 - learning_rate: 0.0015
#
# Epoch 76: LearningRateScheduler setting learning rate to 0.001422460070901693.
# Epoch 76/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8721 - loss: 0.0839
# Epoch 76: dir_acc did not improve from 0.87599
#
# Epoch 76: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8715 - loss: 0.0839 - val_dir_acc: 0.7847 - val_loss: 0.1139 - learning_rate: 0.0014
#
# Epoch 77: LearningRateScheduler setting learning rate to 0.0013226976871298685.
# Epoch 77/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8633 - loss: 0.0861
# Epoch 77: dir_acc did not improve from 0.87599
#
# Epoch 77: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8639 - loss: 0.0861 - val_dir_acc: 0.8611 - val_loss: 0.1098 - learning_rate: 0.0013
#
# Epoch 78: LearningRateScheduler setting learning rate to 0.0012253163028722645.
# Epoch 78/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8665 - loss: 0.0853
# Epoch 78: dir_acc did not improve from 0.87599
#
# Epoch 78: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8666 - loss: 0.0852 - val_dir_acc: 0.8003 - val_loss: 0.1127 - learning_rate: 0.0012
#
# Epoch 79: LearningRateScheduler setting learning rate to 0.0011305120312770046.
# Epoch 79/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8626 - loss: 0.0808
# Epoch 79: dir_acc did not improve from 0.87599
#
# Epoch 79: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8629 - loss: 0.0808 - val_dir_acc: 0.9167 - val_loss: 0.1046 - learning_rate: 0.0011
#
# Epoch 80: LearningRateScheduler setting learning rate to 0.00103847579553028.
# Epoch 80/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8757 - loss: 0.0833
# Epoch 80: dir_acc did not improve from 0.87599
#
# Epoch 80: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8755 - loss: 0.0832 - val_dir_acc: 0.8003 - val_loss: 0.1124 - learning_rate: 0.0010
#
# Epoch 81: LearningRateScheduler setting learning rate to 0.00094939294436246.
# Epoch 81/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8778 - loss: 0.0793
# Epoch 81: dir_acc improved from 0.87599 to 0.87952, saving model to transformer_train_model.keras
#
# Epoch 81: val_dir_acc did not improve from 0.92188
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - dir_acc: 0.8779 - loss: 0.0793 - val_dir_acc: 0.8559 - val_loss: 0.1049 - learning_rate: 9.4939e-04
#
# Epoch 82: LearningRateScheduler setting learning rate to 0.0008634428787804172.
# Epoch 82/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8837 - loss: 0.0800
# Epoch 82: dir_acc did not improve from 0.87952
#
# Epoch 82: val_dir_acc improved from 0.92188 to 0.93229, saving model to transformer_val_model.keras
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - dir_acc: 0.8835 - loss: 0.0801 - val_dir_acc: 0.9323 - val_loss: 0.0990 - learning_rate: 8.6344e-04
#
# Epoch 83: LearningRateScheduler setting learning rate to 0.0007807986907777728.
# Epoch 83/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dir_acc: 0.8845 - loss: 0.0771
# Epoch 83: dir_acc improved from 0.87952 to 0.88487, saving model to transformer_train_model.keras
#
# Epoch 83: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - dir_acc: 0.8845 - loss: 0.0771 - val_dir_acc: 0.8108 - val_loss: 0.1060 - learning_rate: 7.8080e-04
#
# Epoch 84: LearningRateScheduler setting learning rate to 0.0007016268147506584.
# Epoch 84/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - dir_acc: 0.8777 - loss: 0.0801
# Epoch 84: dir_acc did not improve from 0.88487
#
# Epoch 84: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - dir_acc: 0.8779 - loss: 0.0801 - val_dir_acc: 0.8611 - val_loss: 0.1061 - learning_rate: 7.0163e-04
#
# Epoch 85: LearningRateScheduler setting learning rate to 0.000626086692320991.
# Epoch 85/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - dir_acc: 0.8664 - loss: 0.0764
# Epoch 85: dir_acc did not improve from 0.88487
#
# Epoch 85: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - dir_acc: 0.8666 - loss: 0.0765 - val_dir_acc: 0.8611 - val_loss: 0.1053 - learning_rate: 6.2609e-04
#
# Epoch 86: LearningRateScheduler setting learning rate to 0.0005543304512422657.
# Epoch 86/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8750 - loss: 0.0793
# Epoch 86: dir_acc did not improve from 0.88487
#
# Epoch 86: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8752 - loss: 0.0792 - val_dir_acc: 0.8715 - val_loss: 0.0990 - learning_rate: 5.5433e-04
#
# Epoch 87: LearningRateScheduler setting learning rate to 0.00048650259903450645.
# Epoch 87/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8790 - loss: 0.0823
# Epoch 87: dir_acc did not improve from 0.88487
#
# Epoch 87: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8793 - loss: 0.0821 - val_dir_acc: 0.8056 - val_loss: 0.1026 - learning_rate: 4.8650e-04
#
# Epoch 88: LearningRateScheduler setting learning rate to 0.00042273973196535.
# Epoch 88/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8825 - loss: 0.0790
# Epoch 88: dir_acc improved from 0.88487 to 0.88561, saving model to transformer_train_model.keras
#
# Epoch 88: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - dir_acc: 0.8826 - loss: 0.0790 - val_dir_acc: 0.8611 - val_loss: 0.1034 - learning_rate: 4.2274e-04
#
# Epoch 89: LearningRateScheduler setting learning rate to 0.00036317025996334415.
# Epoch 89/100
# 35/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8847 - loss: 0.0764
# Epoch 89: dir_acc did not improve from 0.88561
#
# Epoch 89: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - dir_acc: 0.8845 - loss: 0.0764 - val_dir_acc: 0.8611 - val_loss: 0.1060 - learning_rate: 3.6317e-04
#
# Epoch 90: LearningRateScheduler setting learning rate to 0.00030791414801743875.
# Epoch 90/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.9041 - loss: 0.0783
# Epoch 90: dir_acc improved from 0.88561 to 0.89153, saving model to transformer_train_model.keras
#
# Epoch 90: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - dir_acc: 0.9034 - loss: 0.0782 - val_dir_acc: 0.9271 - val_loss: 0.0989 - learning_rate: 3.0791e-04
#
# Epoch 91: LearningRateScheduler setting learning rate to 0.00025708267458346456.
# Epoch 91/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - dir_acc: 0.8948 - loss: 0.0746
# Epoch 91: dir_acc did not improve from 0.89153
#
# Epoch 91: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8940 - loss: 0.0747 - val_dir_acc: 0.8663 - val_loss: 0.1007 - learning_rate: 2.5708e-04
#
# Epoch 92: LearningRateScheduler setting learning rate to 0.00021077820748413085.
# Epoch 92/100
# 35/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8871 - loss: 0.0737
# Epoch 92: dir_acc did not improve from 0.89153
#
# Epoch 92: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8864 - loss: 0.0739 - val_dir_acc: 0.8559 - val_loss: 0.1017 - learning_rate: 2.1078e-04
#
# Epoch 93: LearningRateScheduler setting learning rate to 0.00016909399775385568.
# Epoch 93/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8970 - loss: 0.0712
# Epoch 93: dir_acc did not improve from 0.89153
#
# Epoch 93: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8965 - loss: 0.0714 - val_dir_acc: 0.8611 - val_loss: 0.1008 - learning_rate: 1.6909e-04
#
# Epoch 94: LearningRateScheduler setting learning rate to 0.00013211399184359196.
# Epoch 94/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8925 - loss: 0.0744
# Epoch 94: dir_acc improved from 0.89153 to 0.89211, saving model to transformer_train_model.keras
#
# Epoch 94: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - dir_acc: 0.8925 - loss: 0.0744 - val_dir_acc: 0.8663 - val_loss: 0.1003 - learning_rate: 1.3211e-04
#
# Epoch 95: LearningRateScheduler setting learning rate to 9.991266256384617e-05.
# Epoch 95/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dir_acc: 0.8869 - loss: 0.0762
# Epoch 95: dir_acc did not improve from 0.89211
#
# Epoch 95: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - dir_acc: 0.8869 - loss: 0.0761 - val_dir_acc: 0.8611 - val_loss: 0.1002 - learning_rate: 9.9913e-05
#
# Epoch 96: LearningRateScheduler setting learning rate to 7.255485910635008e-05.
# Epoch 96/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - dir_acc: 0.8816 - loss: 0.0755
# Epoch 96: dir_acc did not improve from 0.89211
#
# Epoch 96: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - dir_acc: 0.8818 - loss: 0.0754 - val_dir_acc: 0.8715 - val_loss: 0.0990 - learning_rate: 7.2555e-05
#
# Epoch 97: LearningRateScheduler setting learning rate to 5.009567644641898e-05.
# Epoch 97/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - dir_acc: 0.8797 - loss: 0.0757
# Epoch 97: dir_acc did not improve from 0.89211
#
# Epoch 97: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - dir_acc: 0.8799 - loss: 0.0756 - val_dir_acc: 0.8663 - val_loss: 0.0997 - learning_rate: 5.0096e-05
#
# Epoch 98: LearningRateScheduler setting learning rate to 3.258034438900293e-05.
# Epoch 98/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.9031 - loss: 0.0718
# Epoch 98: dir_acc improved from 0.89211 to 0.89597, saving model to transformer_train_model.keras
#
# Epoch 98: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - dir_acc: 0.9028 - loss: 0.0719 - val_dir_acc: 0.8663 - val_loss: 0.0998 - learning_rate: 3.2580e-05
#
# Epoch 99: LearningRateScheduler setting learning rate to 2.0044136481878526e-05.
# Epoch 99/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8750 - loss: 0.0726
# Epoch 99: dir_acc did not improve from 0.89597
#
# Epoch 99: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8754 - loss: 0.0727 - val_dir_acc: 0.8611 - val_loss: 0.1002 - learning_rate: 2.0044e-05
#
# Epoch 100: LearningRateScheduler setting learning rate to 1.25122989794201e-05.
# Epoch 100/100
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - dir_acc: 0.8881 - loss: 0.0753
# Epoch 100: dir_acc did not improve from 0.89597
#
# Epoch 100: val_dir_acc did not improve from 0.93229
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - dir_acc: 0.8881 - loss: 0.0752 - val_dir_acc: 0.8611 - val_loss: 0.0998 - learning_rate: 1.2512e-05

# %%
 t# Load Weights
model.load_weights("transformer_val_model.keras")

# Make predictions
accuracy = model.evaluate(test_sequences, test_labels)[1]
print(accuracy)

# Calculate additional metrics as needed
from sklearn.metrics import r2_score

predictions = model.predict(test_sequences)
r2 = r2_score(test_labels[:, 1], predictions[:, 0])
print(f"R-squared: {r2}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - dir_acc: 0.8789 - loss: 0.0828
# 0.90625
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 333ms/step
# R-squared: 0.9824183863378295
